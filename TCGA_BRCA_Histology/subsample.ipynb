# %%
import pandas as pd

# %%
df = pd.read_csv('final_TCGA_sample_manifest.txt', sep='\t')
df
# Out:
#               sample        Histology_Annotation        PAM50 Tumor_or_normal  \
# 0    TCGA-E9-A5FL-01   Invasive ductal carcinoma        Basal           Tumor
# 1    TCGA-LL-A73Y-01   Invasive ductal carcinoma        Basal           Tumor
# 2    TCGA-AR-A0TS-01   Invasive ductal carcinoma        Basal           Tumor
# 3    TCGA-D8-A27M-01   Invasive ductal carcinoma        Basal           Tumor
# 4    TCGA-BH-A1F0-01   Invasive ductal carcinoma        Basal           Tumor
# ..               ...                         ...          ...             ...
# 870  TCGA-AO-A1KO-01  Invasive lobular carcinoma  normal-like           Tumor
# 871  TCGA-B6-A0RQ-01  Invasive lobular carcinoma  normal-like           Tumor
# 872  TCGA-AC-A3YI-01  Invasive lobular carcinoma  normal-like           Tumor
# 873  TCGA-AR-A2LH-01  Invasive lobular carcinoma  normal-like           Tumor
# 874  TCGA-LL-A73Z-01  Invasive lobular carcinoma  normal-like           Tumor
#
#     er_status_by_ihc pr_status_by_ihc HER2_status Triple_negative_status  \
# 0           Negative         Negative    Negative                    Yes
# 1           Negative         Negative    Positive                     No
# 2           Negative         Negative    Negative                    Yes
# 3           Negative         Negative    Negative                    Yes
# 4           Negative    Indeterminate    Negative                     No
# ..               ...              ...         ...                    ...
# 870         Positive         Positive    Negative                     No
# 871         Positive         Positive    Negative                     No
# 872         Positive         Positive    Negative                     No
# 873         Negative         Negative    Negative                    Yes
# 874         Positive         Positive    Negative                     No
#
#                                        id  \
# 0    e5806a73-54c4-43d1-a44b-db5f43c8e832
# 1    e6a78709-9195-4657-a537-a51e7e7b7c97
# 2    de7f94cb-e730-464b-8012-c2600c5e6510
# 3    aac5d476-06b4-4593-b9aa-611f7cb176f2
# 4    69a45353-526f-441f-aebd-3810a0ca8b24
# ..                                    ...
# 870  03a7acd9-178a-4165-9588-fa63e46f3387
# 871  3c86da8b-a37a-43b6-b76f-d83333f5d653
# 872  3d7fe3ad-45fd-4def-8c5b-6ec117e2c556
# 873  e90eb535-211f-430b-878a-cfd5785f761b
# 874  ab77596c-b37f-4ab2-9416-c5fbee2255b2
#
#                                               filename  \
# 0    TCGA-E9-A5FL-01Z-00-DX1.FB810D6A-303E-45DF-BEF...
# 1    TCGA-LL-A73Y-01Z-00-DX1.50C20931-3AA9-40B4-8A7...
# 2    TCGA-AR-A0TS-01Z-00-DX1.2DB81A2E-16C1-4EE0-817...
# 3    TCGA-D8-A27M-01Z-00-DX1.3020D223-2400-4A2D-8BF...
# 4    TCGA-BH-A1F0-01Z-00-DX1.E1557A67-230A-4337-AEC...
# ..                                                 ...
# 870  TCGA-AO-A1KO-01Z-00-DX1.EEB5E0A0-92B2-42CD-9F7...
# 871  TCGA-B6-A0RQ-01Z-00-DX1.68B4F49D-9F81-4501-BC6...
# 872  TCGA-AC-A3YI-01Z-00-DX1.321C0A32-ABF9-48ED-807...
# 873  TCGA-AR-A2LH-01Z-00-DX1.40D4FD67-FB13-46D9-A20...
# 874  TCGA-LL-A73Z-01Z-00-DX1.C010142E-29C0-411D-9E0...
#
#                                   md5        size
# 0    974165ecf6416fbee667776e21e4e489   841538215
# 1    b3f6cbf507fc5b0781d25cebe9634e29   966989249
# 2    9393ed6eb4a59f8994f4836e446d89ae  2399752529
# 3    9518edda337d05afe2eaea30f4c7b6be   856732025
# 4    3a5740d26e954ce6fa793bd6b2b55da4   462616685
# ..                                ...         ...
# 870  6f93a7b1e45bf2d76104a4b04531c235   402997514
# 871  5cae69812bfcd263a740e4538b6d0595   846469771
# 872  5e861b5cd51cbdaffc3347a3cd8ca4da   742336742
# 873  b21ae947415b9868cf63c53e693bcf06  1540609821
# 874  096ea962fedfe53270b6ed78f104373a   468603959
#
# [875 rows x 12 columns]

# %%
# Sample positive, negative from er_status_by_ihc column and write to file.
er_df = df[df['er_status_by_ihc'].isin(['Positive', 'Negative'])]
er_df_sample = er_df.groupby('er_status_by_ihc').sample(n=100, random_state=1)
er_df_sample.to_csv('er_status_samples.txt', sep='\t', index=False)
